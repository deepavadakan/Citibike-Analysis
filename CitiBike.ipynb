# %%
import pandas as pd

# %%
bike_df = pd.read_csv("202012-citibike-tripdata.csv")
bike_df
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 694  2020-12-01 00:00:03.7770  2020-12-01 00:11:38.3160
# 1                4131  2020-12-01 00:00:09.1730  2020-12-01 01:09:00.2370
# 2                1368  2020-12-01 00:00:28.7470  2020-12-01 00:23:16.9980
# 3                1707  2020-12-01 00:00:34.7680  2020-12-01 00:29:02.6470
# 4                2182  2020-12-01 00:00:36.4030  2020-12-01 00:36:59.0330
# ...               ...                       ...                       ...
# 1088924          2045  2020-12-31 23:58:21.7040  2021-01-01 00:32:27.1570
# 1088925           288  2020-12-31 23:58:37.8400  2021-01-01 00:03:26.3250
# 1088926           152  2020-12-31 23:58:52.8090  2021-01-01 00:01:25.6720
# 1088927           654  2020-12-31 23:59:55.9550  2021-01-01 00:10:50.6050
# 1088928          2589  2020-12-31 23:59:57.4070  2021-01-01 00:43:06.4490
#
#          start station id                   start station name  \
# ...

# %%
bike_group = bike_df.groupby("usertype").agg({'bikeid':'count',
                                                      'tripduration': ['mean','sum']})
bike_group
# Out:
#             bikeid tripduration
#              count         mean        sum
# usertype
# Customer    168312  1797.431966  302529369
# Subscriber  920617   868.879109  799904879

# %%
bike_group = bike_df.groupby("startdate").agg({'bikeid':'count',
                                                      'tripduration': ['mean','sum']})
bike_group
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-2f0a378118be> in <module>
# ----> 1 bike_group = bike_df.groupby("startdate").agg({'bikeid':'count',
#       2                                                       'tripduration': ['mean','sum']})
#       3 bike_group
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed)
#    5808             group_keys=group_keys,
#    5809             squeeze=squeeze,
# -> 5810             observed=observed,
#    5811         )
#    5812
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated)
#     408                 sort=sort,
# ...

# %%
duration = ((pd.to_datetime(bike_df['stoptime']) - pd.to_datetime(bike_df['starttime']))
                                .dt.total_seconds() / 60)
print (duration)
# Out:
# 0          11.575650
# 1          68.851067
# 2          22.804183
# 3          28.464650
# 4          36.377167
#              ...
# 1088924    34.090883
# 1088925     4.808083
# 1088926     2.547717
# 1088927    10.910833
# 1088928    43.150700
# Length: 1088929, dtype: float64
